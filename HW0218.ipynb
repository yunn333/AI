# %% [markdown]
# <a href="https://colab.research.google.com/github/yunn333/AI/blob/main/HW0218.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **第一步：**引入老師的基本四件套
# 1. numpy
# 2. pandas
# 3. matplotlib.pyplot
# 4. seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **第二步：**選定函數圖形 <br>
# 我挑了幾個比較特別的函數圖形 <br>
# 而且主題都與大自然有關！
# - 花朵曲線 🌸 → 看起來像花瓣
# - 蝴蝶曲線 🦋 → 像展翅的蝴蝶
# - 蝸牛曲線 🐌 → 數學與自然的結合

# %% [markdown]
# 先從花朵曲線開始做起 <br>
# 其公式為 $r = a sin(k\theta)$ 或 $r = a cos(k\theta)$ <br>
# 當 $k$ 為奇數時會有 $k$ 片花瓣 <br>
# 當 $k$ 為偶數時則會有 $2k$ 片花瓣

# %%
# 參數設定
theta = np.linspace(0, 2 * np.pi, 1000)
k = 10  # 花瓣數的控制參數
r = np.cos(k * theta)

# 轉換為 x, y
x = r * np.cos(theta)
y = r * np.sin(theta)

# 繪製花朵曲線
plt.figure(figsize=(6,6))
plt.plot(x, y, color='pink', linewidth=2)

plt.title("Flower Curve", fontsize=14)
plt.xticks([])
plt.yticks([])
plt.grid(False)

plt.show()

# %% [markdown]
# 再來是蝴蝶曲線 <br>
# 其公式如下 <br><br>
# $ x = sin(t)(e^{cos(t)} - 2cos(4t) - sin^5(\frac{t}{12})) \\
# y = cos(t)(e^{cos(t)} - 2cos(4t) - sin^5(\frac{t}{12})) $ <br><br>
# 其中 $t$ 介於 $−12\pi$ 到 $12\pi$ 之間

# %%
# 設定參數範圍
t = np.linspace(-12*np.pi, 12*np.pi, 10000)

# 計算蝴蝶曲線的 x, y
x = np.sin(t) * (np.exp(np.cos(t)) - 2*np.cos(4*t) - np.sin(t/12)**5)
y = np.cos(t) * (np.exp(np.cos(t)) - 2*np.cos(4*t) - np.sin(t/12)**5)

# 繪製蝴蝶曲線
plt.figure(figsize=(8,6))
plt.plot(x, y, color='purple', linewidth=2)

# 設定標題
plt.title("Butterfly Curve", fontsize=14)
plt.xticks([])
plt.yticks([])
plt.grid(False)

# 顯示圖形
plt.show()

# %% [markdown]
# 最後是蝸牛曲線 <br>
# 公式如下 <br><br>
# $r = e^{0.2t} \\
# x = rcos(t) \\
# y = rsin(t)$ <br><br>
# 不過主要只會產生如蝸牛殼的螺旋形狀

# %%
# 設定參數範圍
t = np.linspace(0, 4 * np.pi, 1000)

# 設定蝸牛曲線的半徑函數
r = np.exp(0.2 * t)

# 轉換為直角座標
x = r * np.cos(t)
y = r * np.sin(t)

# 繪製蝸牛曲線
plt.figure(figsize=(6,6))
plt.plot(x, y, color='orange', linewidth=2)

# 設定標題
plt.title("Snail Spiral", fontsize=14)
plt.xticks([])
plt.yticks([])
plt.grid(False)

# 顯示圖形
plt.show()

# %% [markdown]
# **以上函數相關程式由 ChatGPT 提供**
